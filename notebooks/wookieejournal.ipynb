# %%
import requests
from bs4 import BeautifulSoup as BS
import pandas as pd
import pickle
import re
from tqdm import tqdm

# %% [markdown]
# This section we will be scraping all Wookieepedia for all Canon articles, and storing them as pickles.

# %%
page_url = 'https://starwars.fandom.com/wiki/Category:Canon_articles'
base_url = 'https://starwars.fandom.com'
pages = {}
page_num = 1

while page_url is not None:
    result = requests.get(page_url)
    content = result.content
    soup = BS(content, "html.parser")
    
    # extract urls
    links = soup.find_all('a', class_='category-page__member-link')
    links_before = len(pages)
    if links:
        for link in links:
            url = base_url + link.get('href')
            key = link.get('href').split('/')[-1]
            if 'Category:' not in key:
                pages[key] = url
        print(f'Page {page_num} - {len(pages) - links_before} new links ({page_url})')
        page_num += 1

    # get next page button
    next_urls = soup.find_all("a", class_='category-page__pagination-next')
    if next_urls:
        new_url = next_urls[0].get('href')
        if new_url == page_url:
            break
        else:
            page_url = new_url
    else:
        page_url = None

print(f'Number of pages: {len(pages)}')

# Save to disk
with open('canon_articles.pkl', 'wb') as f:
    pickle.dump(pages, f, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Page 1 - 199 new links (https://starwars.fandom.com/wiki/Category:Canon_articles)
# Page 2 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=234+BBY%0A234+BBY)
# Page 3 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=511+BBY%0A511+BBY)
# Page 4 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Aargonar%0AAargonar)
# Page 5 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Administrator%0AAdministrator)
# Page 6 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Airship+%28Carnelion+IV%29%0AAirship+%28Carnelion+IV%29)
# Page 7 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=All+Terrain+Armored+Transport+%28original%29%0AAll+Terrain+Armored+Transport+%28original%29)
# Page 8 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Ambush+of+a+rebel+convoy+at+Derra%0AAmbush+of+a+rebel+convoy+at+Derra)
# Page 9 - 199 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Ankot+Station%0AAnkot+Station)
# Page 10 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Aquala%0AAquala)
# Page 11 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Armatan%0AArmatan)
# Page 12 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Asphalt%0AAsphalt)
# Page 13 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Attack+on+Aleen%0AAttack+on+Aleen)
# Page 14 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Aurelia+Tagge%0AAurelia+Tagge)
# Page 15 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Baako+Moradi%0ABaako+Moradi)
# Page 16 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Bantha+Milk+Hot+Chocolate%0ABantha+Milk+Hot+Chocolate)
# Page 17 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Batriok%0ABatriok)
# Page 18 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Battle+of+Starkiller+Base%0ABattle+of+Starkiller+Base)
# Page 19 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Bedlam%0ABedlam)
# Page 20 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Bestine+IV%0ABestine+IV)
# Page 21 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Black+Eleven%0ABlack+Eleven)
# Page 22 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Blood+Monarch%0ABlood+Monarch)
# Page 23 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Bok+Askol%0ABok+Askol)
# Page 24 - 199 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Bothan+Spynet%0ABothan+Spynet)
# Page 25 - 199 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Bright+Star%0ABright+Star)
# Page 26 - 199 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Burg%0ABurg)
# Page 27 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Calderos+Station%0ACalderos+Station)
# Page 28 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Carannia%0ACarannia)
# Page 29 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Cato+Parasitti%0ACato+Parasitti)
# Page 30 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Chadawa%27s+sun%0AChadawa%27s+sun)
# Page 31 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Checkpoint+Five%0ACheckpoint+Five)
# Page 32 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Chorlian+sector%0AChorlian+sector)
# Page 33 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Clash+between+E%27ronoh+and+Eiram%0AClash+between+E%27ronoh+and+Eiram)
# Page 34 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Coba+Dunivee%0ACoba+Dunivee)
# Page 35 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Commissar%0ACommissar)
# Page 36 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Coolant+pump%0ACoolant+pump)
# Page 37 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Corsair+Wars%0ACorsair+Wars)
# Page 38 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Crackdown+on+Pipada%0ACrackdown+on+Pipada)
# Page 39 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=
- 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Star+Herald%0AStar+Herald)
# Page 156 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Sterdic+IV%27s+capital+city%0ASterdic+IV%27s+capital+city)
# Page 157 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Su+Torka%0ASu+Torka)
# Page 158 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Suppressant+shot%0ASuppressant+shot)
# Page 159 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Synthplast%0ASynthplast)
# Page 160 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Tala+Durith%0ATala+Durith)
# Page 161 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Tarkin+Initiative%0ATarkin+Initiative)
# Page 162 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Tee-Six+%28Candor%29%0ATee-Six+%28Candor%29)
# Page 163 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Tezirett+seed%0ATezirett+seed)
# Page 164 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=The+Sinkhole%0AThe+Sinkhole)
# Page 165 - 199 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Tholme%0ATholme)
# Page 166 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Til+the+Spire%0ATil+the+Spire)
# Page 167 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Tomas+Azoras%0ATomas+Azoras)
# Page 168 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Trace+Martez%0ATrace+Martez)
# Page 169 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Trenchenovu%0ATrenchenovu)
# Page 170 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Tuanul%0ATuanul)
# Page 171 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Tyrian+shimmersilk%0ATyrian+shimmersilk)
# Page 172 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Undersecretary%0AUndersecretary)
# Page 173 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Unidentified+bank%0AUnidentified+bank)
# Page 174 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Unidentified+city+planet%0AUnidentified+city+planet)
# Page 175 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Unidentified+Devaronian+Jedi%0AUnidentified+Devaronian+Jedi)
# Page 176 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Unidentified+Frizznoth+Nihil%0AUnidentified+Frizznoth+Nihil)
# Page 177 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Unidentified+Iktotchi+bouncer%0AUnidentified+Iktotchi+bouncer)
# Page 178 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Unidentified+Irizi+speaker%0AUnidentified+Irizi+speaker)
# Page 179 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Unidentified+market%0AUnidentified+market)
# Page 180 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Unidentified+Nothoiin+officer%0AUnidentified+Nothoiin+officer)
# Page 181 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Unidentified+planetoid+%28scrap+pile%29%0AUnidentified+planetoid+%28scrap+pile%29)
# Page 182 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Unidentified+Rodian+child%0AUnidentified+Rodian+child)
# Page 183 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Unidentified+ST-series+military+strategic+analysis+and+tactics+droid+%28Anaxes%29%0AUnidentified+ST-series+military+strategic+analysis+and+tactics+droid+%28Anaxes%29)
# Page 184 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Unidentified+Toydarian+royal+guard%0AUnidentified+Toydarian+royal+guard)
# Page 185 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Unidentified+Weequay+woman%0AUnidentified+Weequay+woman)
# Page 186 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Uscru+Entertainment+District%0AUscru+Entertainment+District)
# Page 187 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Valron%0AValron)
# Page 188 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Vel+Sartha%0AVel+Sartha)
# Page 189 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Vice+Chairman%0AVice+Chairman)
# Page 190 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Volzang+Li-Thrull%0AVolzang+Li-Thrull)
# Page 191 - 199 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=War+on+Kashyyyk%0AWar+on+Kashyyyk)
# Page 192 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Wells%0AWells)
# Page 193 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Wind-truster%0AWind-truster)
# Page 194 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Wurrek%0AWurrek)
# Page 195 - 199 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Y-45+armored+transport+hauler%0AY-45+armored+transport+hauler)
# Page 196 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=YOL+general+worker%0AYOL+general+worker)
# Page 197 - 200 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Zarra%0AZarra)
# Page 198 - 80 new links (https://starwars.fandom.com/wiki/Category:Canon_articles?from=Zoneb%0AZoneb)
# Number of pages: 39460

# %% [markdown]
# We have created the dictionary with all current canon articles.  Now we will scrape them for Title, Sidebar information, and links to other canon articles.

# %%
scraped = {}
failed = {}
partition_size = 5000
folder = '../WPscraped/'

for ix, (key, page_url) in tqdm(enumerate(pages.items()), total=(len(pages))):
    try:
        # Get page
        result = requests.get(page_url)
        content = result.content
        soup = BS(content, "html.parser")

        # Get title
        heading = soup.find('h1', id='firstHeading')
        if heading is None: continue
        heading = heading.text

        # Extract Sidebar
        is_character = False
        side_bar = {}
        sec = soup.find_all('section', class_='pi-item')
        for s in sec:
            title = s.find('h2')
            if title is None:
                title = '<no category>'
            else:
                title = title.text
            side_bar[title] = {}
            items = s.find_all('div', class_='pi-item')
            for item in items:
                attr = item.find('h3', class_='pi-data-label')
                if attr is None:
                    attr = '<no attribute>'
                else:
                    attr = attr.text
                if attr == 'Species': is_character = True
                value = re.sub("[\(\[].*?[\)\]]" ,'', '], '.join(item.find('div', class_='pi-data-value').text.split(']')))
                value = value.strip()[:-1].replace(',,', ',')
                if ',' in value:
                    value = [i.strip() for i in value.split(',') if i.strip() != '']
                side_bar[title][attr] = value

        # Raw page content
        raw_content = soup.find('div', class_='mw-parser-output')
        if raw_content is not None:
            for raw_paragraph in raw_content.find_all('p', recursive=False):
                if 'aside' in str(raw_paragraph): continue
                break
            paragraph = value = re.sub("[\(\[].*?[\)\]]" ,'', raw_paragraph.text)

            # cross-links
            keywords = []
            for link in raw_content.find_all('a'):
                part = link.get('href')
                if part is not None:
                    part = part.split('/')[-1] 
                    if part in pages.keys() and part != key:
                        keywords.append(part)
            keywords = list(set(keywords))
        else:
            # Empty page
            keywords = []
            paragraph = ''

        # Data object
        scraped[key] = {
            'url': page_url,
            'title': heading,
            'is_character': is_character,
            'side_bar': side_bar,
            'paragraph': paragraph,
            'crosslinks': keywords,
        }

        # save partition
        if (ix + 1) % partition_size == 0:
            last_number = (ix+1) // partition_size
            fn = folder + f'starwars_all_canon_data_{last_number}.pickle'
            with open(fn, 'wb') as f:
                pickle.dump(scraped, f, protocol=pickle.HIGHEST_PROTOCOL)
            scraped = {}
    except:
        print('Failed!')
        failed[key] = page_url
    
# Save final part to disk
fn = folder + f'starwars_all_canon_data_{last_number + 1}.pickle'
with open(fn, 'wb') as f:
    pickle.dump(scraped, f, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# 100%|██████████| 39460/39460 [4:51:26<00:00,  2.26it/s]

# %% [markdown]
# Now that we have the canon data pulled and scraped, and unnecessary pieces of data pulled out, we have our clean datasets we can use to extract dataframes for characters, planets, and vehicles.

# %%
from pathlib import Path
import urllib


files = sorted(Path('../WPscraped').glob('*.pickle'))
files
# Out:
# [WindowsPath('../WPscraped/starwars_all_canon_data_1.pickle'),
#  WindowsPath('../WPscraped/starwars_all_canon_data_2.pickle'),
#  WindowsPath('../WPscraped/starwars_all_canon_data_3.pickle'),
#  WindowsPath('../WPscraped/starwars_all_canon_data_4.pickle'),
#  WindowsPath('../WPscraped/starwars_all_canon_data_5.pickle'),
#  WindowsPath('../WPscraped/starwars_all_canon_data_6.pickle'),
#  WindowsPath('../WPscraped/starwars_all_canon_data_7.pickle'),
#  WindowsPath('../WPscraped/starwars_all_canon_data_8.pickle')]

# %%
data = {}
for fn in files:
    with open(fn, 'rb') as f:
        part = pickle.load(f)
    data.update(part)

len(data)
# Out:
# 39460

# %%
def remove_url_stuff(text):
    return urllib.parse.unquote(text).replace('"', '').replace("'", '')

# %%
cleaned = {}
for key, value in tqdm(data.items()):
    new_key = remove_url_stuff(key)
    cleaned[new_key] = value
    cleaned[new_key]['crosslinks'] = [remove_url_stuff(crosslink) for crosslink in value['crosslinks']]
data = cleaned
# Out:
# 100%|██████████| 39460/39460 [00:01<00:00, 36189.95it/s]
